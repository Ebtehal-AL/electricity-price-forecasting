# %%
import pandas as pd

file_path = "../data/raw/QuarterHourly.xlsx"

df = pd.read_excel(file_path)

df.head()
# Out:
# C:\Users\ebteh\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                Datenkategorie: Großhandelspreise Unnamed: 1 Unnamed: 2  \
# 0                                  Region: DE-LU        NaN        NaN
# 1  Zeitraum: 01.10.2025 00:00 - 01.03.2026 00:00        NaN        NaN
# 2                        Stand: 21.04.2026 14:23        NaN        NaN
# 3               (c) Bundesnetzagentur | SMARD.de        NaN        NaN
# 4                       Auflösung: Viertelstunde        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df.shape
# Out:
# (14509, 19)

# %%
df.columns
# Out:
# Index(['Datenkategorie: Großhandelspreise', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18'],
#       dtype='str')

# %%
df.head(20)
# Out:
#                     Datenkategorie: Großhandelspreise        Unnamed: 1  \
# 0                                       Region: DE-LU               NaN
# 1       Zeitraum: 01.10.2025 00:00 - 01.03.2026 00:00               NaN
# 2                             Stand: 21.04.2026 14:23               NaN
# 3                    (c) Bundesnetzagentur | SMARD.de               NaN
# 4                            Auflösung: Viertelstunde               NaN
# 5                              Berechnete Auflösung:                NaN
# 6   Originalauflösung: Deutschland/Luxemburg, Öste...               NaN
# 7                                                 NaN               NaN
# 8                                           Datum von         Datum bis
# 9                                    01.10.2025 00:00  01.10.2025 00:15
# 10                                   01.10.2025 00:15  01.10.2025 00:30
# 11                                   01.10.2025 00:30  01.10.2025 00:45
# ...
